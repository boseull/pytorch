# %% [markdown]
# <a href="https://colab.research.google.com/github/boseull/pytorch/blob/main/pytorch_transform.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# transform : feature 변경 (FashionMNIST : PIL image -> normalize feature)
# target_transform : label 변경 (FashionMNIST : 정수 -> one-hot)

# %%
import torch
from torchvision import datasets
from torchvision.transforms import ToTensor, Lambda

# %%
ds = datasets.FashionMNIST(root="data", train=True, download=True, transform=ToTensor(), target_transform=Lambda(lambda y: torch.zeros(10, dtype=torch.float).scatter_(0, torch.tensor(y), value=1)))
# Out:
# ...
#   0%|          | 0/26421880 [00:00<?, ?it/s]
# Extracting data/FashionMNIST/raw/train-images-idx3-ubyte.gz to data/FashionMNIST/raw
#
# ...
#   0%|          | 0/29515 [00:00<?, ?it/s]
# Extracting data/FashionMNIST/raw/train-labels-idx1-ubyte.gz to data/FashionMNIST/raw
#
# ...
#   0%|          | 0/4422102 [00:00<?, ?it/s]
# Extracting data/FashionMNIST/raw/t10k-images-idx3-ubyte.gz to data/FashionMNIST/raw
#
# ...
#   0%|          | 0/5148 [00:00<?, ?it/s]
# Extracting data/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz to data/FashionMNIST/raw
# ...

# %% [markdown]
# Totensor : PIL Image, Numpy array -> FloatTensor, 픽셀값을 [0, 1]사이로 지정
# Lambda : 총 라벨 수 지정(10) -> scatter_이용해서 주어진 정답에 해당하는 위치를 value(1)로 지정
